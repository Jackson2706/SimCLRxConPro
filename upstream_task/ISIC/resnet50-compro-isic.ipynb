# %% [markdown]
# # 1. Dataset

# %%
import torch
from torch.utils.data import Dataset
import numpy as np
import cv2
from torch import randint
import os
import random
from torchvision import transforms
import pandas as pd
from PIL import Image


def seed_everything(seed: int):
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

mean = [0.7635  , 0.5461, 0.5705 ]
std = [0.1412 , 0.1529 , 0.1703]
data_transforms = {
    'training': transforms.Compose([
        transforms.ToPILImage(),
        transforms.RandomHorizontalFlip(p=0.3),
        transforms.RandomApply(torch.nn.ModuleList([transforms.ColorJitter(), ]), p=0.3),
        transforms.RandomApply(torch.nn.ModuleList([transforms.GaussianBlur(kernel_size=3), ]), p=0.3),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'valid': transforms.Compose([
        transforms.ToPILImage(),
        transforms.ToTensor(),
        transforms.Normalize(mean, std)
    ]),
    'test': transforms.Compose([
        transforms.ToPILImage(),
        transforms.ToTensor(),
    ]),
}


danger_levels_to_id = {
    'NV': 1,       # Nevus
    'DF': 2,       # Dermatofibroma
    'BKL': 3,    # Actinic Keratosis
    'VASC': 4,     # Vascular Lesions
    'AKIEC': 5,      # Basal Cell Carcinoma (BCC)
    'BCC': 6,      # Squamous Cell Carcinoma (SCC)
    'MEL': 7       # Melanoma
}

def get_non_zero_columns(row, columns):
    return [danger_levels_to_id[col] for col in columns if row[col] != 0][0]

class ISICCompDataset(Dataset):
    def __init__(self,
                data_path = "/mnt/d/AiThings/SimCLRxConPro/Dataset/ISIC/ISIC2018_Task3_Training_Input",
                meta_data = "/mnt/d/AiThings/SimCLRxConPro/Dataset/ISIC/ISIC2018_Task3_Training_GroundTruth.csv",
                phase = "training",
                transform = None,
                datalen = 100,
                mode = "multiclass_contrastive",
                seed = None):
        self.phase = phase
        self.datalen = datalen
        self.data_path = data_path
        self.transform = data_transforms[self.phase] if (transform == None) else transform
        self.mode = mode
        df = pd.read_csv(meta_data)

        # List of columns to check for non-zero values (excluding 'image')
        columns_to_check = df.columns[1:]

        # Apply the function to get non-zero columns
        self.data = df[['image']].copy()
        self.data['label'] = df.apply(lambda row: get_non_zero_columns(row, columns_to_check), axis=1)
        self.danger_levels = []
        for i in range(1,8):
            self.danger_levels.append(self.data[self.data['label'] == 1])
        self.name_of_classes = [1,2,3,4,5,6,7]
        self.len_of_classes = [len(self.danger_levels[i].index) for i in range(7)]
        self.paths1 = []
        self.paths2 = []
        self.listi1 = []
        self.listi2 = []
        self.complabels = []
        curlen = 0
        self.imagesinclass0 = self.danger_levels[0]
        seed_everything(seed)
        while(curlen < self.datalen):
            if mode == "multiclass_contrastive":
                if random.randint(0, 1) == 0:
                    i1 = random.randint(0, 6)
                    i2 = random.randint(0, 6)
                else:
                    i1 = random.randint(0, 6)
                    i2 = i1

                self.listi1.append(i1)
                self.listi2.append(i2)
                self.paths1.append(self.get_path(self.danger_levels[i1], randint(0, self.len_of_classes[i1], (1, ))[0]))
                self.paths2.append(self.get_path(self.danger_levels[i2], randint(0, self.len_of_classes[i2], (1, ))[0]))
                self.complabels.append((i1==i2)*1)
                curlen = curlen + 1
            elif mode == 'binary_contrastive':
                modee = random.randint(0, 3)
                if (modee == 0):
                    i1 = 0
                    i2 = 0
                elif (modee == 1):
                    i1 = random.randint(1, 4)
                    i2 = random.randint(1, 4)
                elif (modee == 2):
                    i1 = 0
                    i2 = random.randint(1, 4)
                else:
                    i2 = 0
                    i1 = random.randint(1, 4)
                # pickimageA = randint(0, lenofclass[random_pick_2class[0]], (1,))
                self.listi1.append(i1)
                self.listi2.append(i2)
                self.paths1.append(self.get_path(self.danger_levels[i1], randint(0, self.len_of_classes[i1], (1,))[0]))
                self.paths2.append(self.get_path(self.danger_levels[i2], randint(0, self.len_of_classes[i2], (1,))[0]))
                self.complabels.append((((i1 == 0) and (i2 == 0)) or ((i1 != 0) and (i2 != 0))) * 1)
                curlen = curlen + 1
            elif (mode == 'severity_comparison'):
                i1 = random.randint(1, 4)
                i2 = random.randint(1, 4)
                # pickimageA = randint(0, lenofclass[random_pick_2class[0]], (1,))
                self.listi1.append(i1)
                self.listi2.append(i2)
                self.paths1.append(self.get_path(self.danger_levels[i1], randint(0, self.len_of_classes[i1], (1,))[0]))
                self.paths2.append(self.get_path(self.danger_levels[i2], randint(0, self.len_of_classes[i2], (1,))[0]))
                self.complabels.append(((i1 > i2)) * 1)
                curlen = curlen + 1

    def get_score(self, data, index):
        birads = data['label'].iloc[index.item()]
        score = eval(birads[-1])
        return score

    def get_path(self, data, index):
        image_name = data['image'].iloc[index.item()]
        image_path = os.path.join(self.data_path, image_name + '.jpg')
        return (image_path)

    def __getitem__(self, index):
        imageA = cv2.imread(self.paths1[index])
        imageB = cv2.imread(self.paths2[index])

        label = self.complabels[index]

        imageA = self.transform(imageA)
        imageB = self.transform(imageB)
        if self.mode == 'severity_comparison':
            ref_img = self.get_ref_images()
            return (imageA, imageB), ref_img, label, (self.listi1[index], self.listi2[index])
        else:
            return (imageA, imageB), label, (self.listi1[index], self.listi2[index])

    def get_ref_images(self):
        ref_img = self.get_path(self.imagesinclass0, randint(0, len(self.imagesinclass0), (1,))[0])
        ref_img = cv2.imread(ref_img)
        ref_img = self.transform(ref_img)

        return ref_img

    def __len__(self):
        return self.datalen

# %% [markdown]
# # 2. Model

# %%
from torch import nn
def get_default_fc(in_features=2048, model='siamese1', ncriteria=10):
    if(model=='siamese1'):
        ret =  nn.Sequential(torch.nn.Linear(in_features, 256),
                                torch.nn.ReLU(),
                                torch.nn.Dropout(0.1),
                                torch.nn.Linear(256, 64),
                                torch.nn.ReLU(),
                                torch.nn.Dropout(0.1),
                                torch.nn.Linear(64, 1))
    else:
        ret =  nn.Sequential(torch.nn.Linear(in_features, 256),
                                torch.nn.ReLU(),
                                torch.nn.Dropout(0.1),
                                torch.nn.Linear(256, 64),
                                torch.nn.ReLU(),
                                torch.nn.Dropout(0.1),
                                torch.nn.Linear(64, ncriteria))
    return ret
class ResNetSimCLR(nn.Module):

    def __init__(self, base_model, out_dim):
        super(ResNetSimCLR, self).__init__()
        self.resnet_dict = {"resnet18": models.resnet18(weights='ResNet18_Weights.DEFAULT', num_classes=out_dim),
                            "resnet50": models.resnet50(weights='ResNet50_Weights.DEFAULT', num_classes=out_dim),
                            "resnet101": models.resnet101(weights='ResNet101_Weights.DEFAULT', num_classes=out_dim),
                            "densenet121": models.densenet121(weights='DenseNet121_Weights.DEFAULT', num_classes=out_dim)}

        self.backbone = self._get_basemodel(base_model)
        dim_mlp = self.backbone.fc.in_features

        # add mlp projection head
        self.backbone.fc = nn.Sequential(nn.Linear(dim_mlp, dim_mlp), nn.ReLU(), self.backbone.fc)

    def _get_basemodel(self, model_name):
        try:
            model = self.resnet_dict[model_name]
        except KeyError:
            raise InvalidBackboneError(
                "Invalid backbone architecture. Check the config file and pass one of: resnet18 or resnet50")
        else:
            return model

    def forward(self, x):
        return self.backbone(x)

# %%
from torchvision import models, transforms

def get_feature_extractor(feature_extractor = 'resnet50', fcnet = None, cotrain=True, ncriteria=10, model='siamese1', simclr = None):
    if(feature_extractor == 'resnet50'):    
        fextractor = models.resnet50(weights='ResNet50_Weights.DEFAULT')
        in_features = 2048
        if(simclr):
            print('load simclr resnet')
            ressimclr = ResNetSimCLR('resnet50', 1000)
            state_dict = torch.load(simclr)
            ressimclr.load_state_dict(state_dict['state_dict'])
            fextractor = ressimclr.backbone
        fextractor.fc = get_default_fc(in_features, model=model, ncriteria=ncriteria) if (fcnet == None) else fcnet
    elif(feature_extractor == 'resnet101'):    
        fextractor = models.resnet101(weights='ResNet101_Weights.DEFAULT')
        in_features = 2048
        if(simclr):
            print('load simclr resnet')
            ressimclr = ResNetSimCLR('resnet101', 1000)
            state_dict = torch.load(simclr)
            ressimclr.load_state_dict(state_dict['state_dict'])
            fextractor = ressimclr.backbone
        fextractor.fc = get_default_fc(in_features, model=model, ncriteria=ncriteria) if (fcnet == None) else fcnet
    elif(feature_extractor == 'densnet121'):
        fextractor = models.densenet121(weights='DenseNet121_Weights.DEFAULT')
        in_features = 1024
        fextractor.classifier = get_default_fc(in_features, model=model, ncriteria=ncriteria) if (fcnet == None) else fcnet
        # fextractor._modules['classifier'] = fextractor._modules.pop('classifier')
    elif(feature_extractor == 'vgg19'):
        fextractor = models.vgg19()
        fextractor.load_state_dict(torch.load('./pretrained/vgg19-dcbb9e9d.pth'))
        in_features = 25088 # https://www.geeksforgeeks.org/vgg-16-cnn-model/ length of vgg19
        fextractor.classifier = get_default_fc(in_features, model=model, ncriteria=ncriteria) if (fcnet == None) else fcnet 
        # fextractor._modules['fc'] = fextractor._modules.pop('classifier')
    elif(feature_extractor == 'vit16'):
        fextractor = models.vit_b_16()
        in_features = 768
        fextractor.load_state_dict(torch.load('./pretrained/vit_b_16-c867db91.pth'))
        fextractor.heads.head = get_default_fc(in_features, model=model, ncriteria=ncriteria) if (fcnet == None) else fcnet 
        # fextractor.classifier = get_default_fc(in_features) if (fcnet == None) else fcnet
    else:
        assert False, 'No feature extractor founded'

    for param in fextractor.parameters():
            param.requires_grad = cotrain
    if(feature_extractor == 'resnet50' or feature_extractor == 'resnet101'):        
        for param in fextractor.fc.parameters():
            param.requires_grad = True
    elif(feature_extractor == 'vit16'):
        for param in fextractor.heads.parameters():
            param.requires_grad = True
    else:
        for param in fextractor.classifier.parameters():
            param.requires_grad = True

    return fextractor

# %%
class SiameseNetwork101(nn.Module):
    """
    Siamese neural network
    Modified from: https://hackernoon.com/facial-similarity-with-siamese-networks-in-pytorch-9642aa9db2f7
    Siamese ResNet-101 from Pytorch library
    """ 
    def __init__(self):
        super(SiameseNetwork101, self).__init__()
        # note that resnet101 requires 3 input channels, will repeat grayscale image x3
        self.cnn1 = get_feature_extractor(feature_extractor='resnet50', cotrain=False)# , simclr='/mnt/c/Users/PCM/Dropbox/pretrained/SimCLR/checkpoint_10_02102023.pth.tar')
        self.cnn1.fc = nn.Sequential(torch.nn.Linear(2048, 1000),
                                torch.nn.ReLU(),
                                torch.nn.Dropout(0.1),
                                torch.nn.Linear(1000, 256))
    
    def forward_once(self, x):
        output = self.cnn1(x)
        return output

    def forward(self, input1, input2):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        return output1, output2

# %%
class SeverityModel(nn.Module):
    """
    Siamese neural network
    Modified from: https://hackernoon.com/facial-similarity-with-siamese-networks-in-pytorch-9642aa9db2f7
    Siamese ResNet-101 from Pytorch library
    """ 
    def __init__(self, path2pretrained=''):
        super(SeverityModel, self).__init__()
        # note that resnet101 requires 3 input channels, will repeat grayscale image x3
        self.bestsimese50simclr = SiameseNetwork101()
        if (path2pretrained):
            state_dict = torch.load(path2pretrained)
            self.bestsimese50simclr.load_state_dict(state_dict["model_state_dict"])
        self.bestsimese50simclr.cnn1.add_module('fc2',
            nn.Sequential(torch.nn.Linear(256, 256),
                          torch.nn.ReLU(),
                        torch.nn.Dropout(0.1),
                        torch.nn.Linear(256, 256)))
    
    def forward_once(self, x):
        output = self.bestsimese50simclr.cnn1.fc2(self.bestsimese50simclr.cnn1(x))
        return output

    def forward(self, input1, input2, refinput):
        output1 = self.forward_once(input1)
        output2 = self.forward_once(input2)
        refinput = self.bestsimese50simclr.cnn1(refinput)
        return output1, output2, refinput

# %% [markdown]
# # 3. Loss function

# %%
import torch
from torch import nn

class PreferenceComparisonLoss(nn.Module):
    """
    Contrastive loss function for preference comparison.
    Based on: http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    Modified from: https://hackernoon.com/facial-similarity-with-siamese-networks-in-pytorch-9642aa9db2f7
    """ 

    def __init__(self, margin=2.0):
        super(PreferenceComparisonLoss, self).__init__()
        self.margin = margin
        self.bce_loss = nn.BCEWithLogitsLoss()

    def forward(self, output1, output2, label, ref):
        # Calculate cosine similarity between outputs and reference
        cosine_distanceA = nn.functional.cosine_similarity(output1, ref)
        cosine_distanceB = nn.functional.cosine_similarity(output2, ref)
        
        # Calculate the difference in cosine similarities
        similarity_diff = cosine_distanceA - cosine_distanceB
        
        # Apply sigmoid to the difference
        similarity_diff_sigmoid = nn.Sigmoid()(similarity_diff)
        
        # Calculate binary cross-entropy loss
        loss_comparison = self.bce_loss(similarity_diff_sigmoid, label.float())
        
        return loss_comparison

# %% [markdown]
# # 4. Train pipeline

# %%
import torch
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim import lr_scheduler
import os


def train_model(model, train_dataset, val_dataset, checkpoint_folder, num_epochs=10, batch_size=32,
                learning_rate=0.001):
    """
    Train the model using the provided datasets.

    Args:
    - model: The model to be trained
    - train_dataset: Dataset for training
    - val_dataset: Dataset for validation
    - checkpoint_folder: Folder to store checkpoints
    - num_epochs: Number of epochs for training
    - batch_size: Batch size for training
    - learning_rate: Learning rate for optimization

    Returns:
    - model: Trained model
    - train_losses: List of training losses
    - val_losses: List of validation losses
    """
    # Create the checkpoint folder if it doesn't exist
    if not os.path.exists(checkpoint_folder):
        os.makedirs(checkpoint_folder)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"Device: {device}")
    # Define data loaders for training and validation
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=True)

    # Define loss function and optimizer
    criterion = PreferenceComparisonLoss()
    optimizer = optim.SGD([{'params': model.bestsimese50simclr.cnn1.conv1.parameters()},
                        {'params': model.bestsimese50simclr.cnn1.layer1.parameters()},
                        {'params': model.bestsimese50simclr.cnn1.layer2.parameters()},
                        {'params': model.bestsimese50simclr.cnn1.layer3.parameters()},
                        {'params': model.bestsimese50simclr.cnn1.layer4.parameters()},
                        {'params': model.bestsimese50simclr.cnn1.fc.parameters(), 'lr':learning_rate*10}], lr=learning_rate, momentum=0.9)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

    # Lists to store training and validation losses
    train_losses = []
    val_losses = []

    # Variables to keep track of the best model and its performance
    best_val_loss = float('inf')
    best_model_state = None

    model = model.to(device)
    print("Training started...")
    for epoch in range(num_epochs):
        torch.cuda.empty_cache()
        print("*" * 100)
        print(f"Epoch [{epoch + 1}/{num_epochs}]:")
        model.train()
        running_train_loss = 0.0
        for i, (inputs,ref, labels, _) in enumerate(train_loader):
            optimizer.zero_grad()
            # Forward pass
            inputA = inputs[0].to(device)
            inputB = inputs[1].to(device)
            ref = ref.to(device)
            labels = labels.to(device)
            output1, output2, ref_output = model(inputA, inputB, ref)
            # Compute loss
            loss = criterion(output1, output2, labels, ref_output)
            # Backward pass
            loss.backward()
            optimizer.step()
            running_train_loss += loss.item()

            if i % 200 == 0:
                print(f"\t Batch [{i}/{len(train_loader)}], Train Loss: {loss.item():.4f}")

        # Compute average training loss for the epoch
        epoch_train_loss = running_train_loss / len(train_loader)
        train_losses.append(epoch_train_loss)

        # Validation loop
        model.eval()
        running_val_loss = 0.0
        with torch.no_grad():
            for i, (inputs,ref, labels, _) in enumerate(val_loader):
                inputA = inputs[0].to(device)
                inputB = inputs[1].to(device)
                ref = ref.to(device)
                labels = labels.to(device)
                output1, output2, ref_output = model(inputA, inputB, ref)
                # Compute loss
                loss = criterion(output1, output2, labels, ref_output)
                running_val_loss += loss.item()

                if i % 100 == 0:
                    print(
                        f"Epoch [{epoch + 1}/{num_epochs}], Validation Batch [{i}/{len(val_loader)}], Val Loss: {loss.item():.4f}")

        # Compute average validation loss for the epoch
        epoch_val_loss = running_val_loss / len(val_loader)
        val_losses.append(epoch_val_loss)

        # Save the model checkpoint for every epoch (last model)
        torch.save({
            'epoch': epoch,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'val_loss': epoch_val_loss
        }, os.path.join(checkpoint_folder, f'last.pt'))

        # Save the best model checkpoint based on validation loss
        if epoch_val_loss < best_val_loss:
            print(f"Best weight is saved at epoch {epoch + 1}")
            best_val_loss = epoch_val_loss
            best_model_state = model.state_dict()
            torch.save({
                'epoch': epoch,
                'model_state_dict': best_model_state,
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': best_val_loss
            }, os.path.join(checkpoint_folder, f'best.pt'))

        # Print progress
        print(f"Validation, Train Loss: {epoch_train_loss:.4f}, Val Loss: {epoch_val_loss:.4f}")
        print("*" * 100)
        scheduler.step()
    print("Training completed.")

    return model, train_losses, val_losses

# %%
import datetime
now = datetime.datetime.now()

config = {
    "train_annotation_data_path":"/mnt/d/AiThings/SimCLRxConPro/Dataset/ISIC/ISIC2018_Task3_Training_GroundTruth.csv",
    "train_image_folder_path": "/mnt/d/AiThings/SimCLRxConPro/Dataset/ISIC/ISIC2018_Task3_Training_Input",
    "valid_annotation_data_path":"/mnt/d/AiThings/SimCLRxConPro/Dataset/ISIC/ISIC2018_Task3_Validation_GroundTruth.csv",
    "valid_image_folder_path": "/mnt/d/AiThings/SimCLRxConPro/Dataset/ISIC/ISIC2018_Task3_Validation_Input",
    "data_length": 100000,
    "learning_rate":1e-3,
    "num_epoch": 10,
    "batch_size": 4,
    "checkpoint": "/mnt/d/AiThings/SimCLRxConPro/upstream_task/ISIC/foundation_model/conpro/best.pt",
    "checkpoint_folder": f"/mnt/d/AiThings/SimCLRxConPro/upstream_task/ISIC/foundation_model/conpro"
}

# %%
import yaml

train_dataset = ISICCompDataset(data_path = config["train_image_folder_path"],
                                meta_data = config["train_annotation_data_path"],
                                phase = "training",
                                mode = "severity_comparison",
                                datalen = config["data_length"],
                                seed=0)
valid_dataset = ISICCompDataset(data_path = config["valid_image_folder_path"],
                                meta_data = config["valid_annotation_data_path"],
                                phase = "valid",
                                mode = "severity_comparison",
                                datalen = 1000,
                                seed=0)



model = SeverityModel()

if config["checkpoint"]:
    checkpoint = torch.load(config["checkpoint"])
    model.load_state_dict(checkpoint["model_state_dict"])

train_model(model=model, train_dataset=train_dataset,
            val_dataset=valid_dataset, num_epochs=config["num_epoch"],
            batch_size=config["batch_size"], learning_rate=config["learning_rate"],
            checkpoint_folder=config["checkpoint_folder"]
            )
# Out:
# /tmp/ipykernel_529416/4099962822.py:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(config["checkpoint"])
# Device: cuda
# Training started...
# ****************************************************************************************************
# Epoch [1/10]:
# 	 Batch [0/25000], Train Loss: 0.7194
# 	 Batch [200/25000], Train Loss: 0.6009
# 	 Batch [400/25000], Train Loss: 0.7204
# 	 Batch [600/25000], Train Loss: 0.8516
# 	 Batch [800/25000], Train Loss: 0.9721
# 	 Batch [1000/25000], Train Loss: 0.7284
# 	 Batch [1200/25000], Train Loss: 0.7315
# 	 Batch [1400/25000], Train Loss: 0.9728
# 	 Batch [1600/25000], Train Loss: 0.9763
# 	 Batch [1800/25000], Train Loss: 0.8548
# 	 Batch [2000/25000], Train Loss: 0.9663
# 	 Batch [2200/25000], Train Loss: 0.5923
# 	 Batch [2400/25000], Train Loss: 0.5954
# 	 Batch [2600/25000], Train Loss: 0.8522
# 	 Batch [2800/25000], Train Loss: 0.7165
# 	 Batch [3000/25000], Train Loss: 0.9747
# 	 Batch [3200/25000], Train Loss: 0.7340
# 	 Batch [3400/25000], Train Loss: 0.7228
# 	 Batch [3600/25000], Train Loss: 0.7194
# 	 Batch [3800/25000], Train Loss: 0.9715
# 	 Batch [4000/25000], Train Loss: 0.7211
# 	 Batch [4200/25000], Train Loss: 0.8471
# 	 Batch [4400/25000], Train Loss: 0.7274
# 	 Batch [4600/25000], Train Loss: 0.7188
# 	 Batch [4800/25000], Train Loss: 0.4755
# 	 Batch [5000/25000], Train Loss: 0.6074
# 	 Batch [5200/25000], Train Loss: 0.8442
# 	 Batch [5400/25000], Train Loss: 0.9751
# 	 Batch [5600/25000], Train Loss: 0.8436
# 	 Batch [5800/25000], Train Loss: 0.6088
# 	 Batch [6000/25000], Train Loss: 0.7256
# 	 Batch [6200/25000], Train Loss: 0.8506
# 	 Batch [6400/25000], Train Loss: 0.8488
# 	 Batch [6600/25000], Train Loss: 0.5887
# 	 Batch [6800/25000], Train Loss: 0.8471
# 	 Batch [7000/25000], Train Loss: 0.7208
# 	 Batch [7200/25000], Train Loss: 0.7151
# 	 Batch [7400/25000], Train Loss: 0.7241
# 	 Batch [7600/25000], Train Loss: 0.5961
# 	 Batch [7800/25000], Train Loss: 0.7211
# 	 Batch [8000/25000], Train Loss: 0.7220
# 	 Batch [8200/25000], Train Loss: 0.7204
# 	 Batch [8400/25000], Train Loss: 0.7222
# 	 Batch [8600/25000], Train Loss: 0.5967
# 	 Batch [8800/25000], Train Loss: 0.7130
# 	 Batch [9000/25000], Train Loss: 0.7209
# 	 Batch [9200/25000], Train Loss: 0.7308
# 	 Batch [9400/25000], Train Loss: 0.8555
# 	 Batch [9600/25000], Train Loss: 0.7293
# 	 Batch [9800/25000], Train Loss: 0.9749
# 	 Batch [10000/25000], Train Loss: 0.9731
# 	 Batch [10200/25000], Train Loss: 0.8476
# 	 Batch [10400/25000], Train Loss: 0.7226
# 	 Batch [10600/25000], Train Loss: 0.9699
# 	 Batch [10800/25000], Train Loss: 0.6024
# 	 Batch [11000/25000], Train Loss: 0.5971
# 	 Batch [11200/25000], Train Loss: 0.8501
# 	 Batch [11400/25000], Train Loss: 0.8498
# 	 Batch [11600/25000], Train Loss: 0.5969
# 	 Batch [11800/25000], Train Loss: 0.7289
# 	 Batch [12000/25000], Train Loss: 0.9752
# 	 Batch [12200/25000], Train Loss: 0.7321
# 	 Batch [12400/25000], Train Loss: 0.7240
# 	 Batch [12600/25000], Train Loss: 0.8424
# 	 Batch [12800/25000], Train Loss: 0.9769
# 	 Batch [13000/25000], Train Loss: 0.7236
# 	 Batch [13200/25000], Train Loss: 0.9744
# 	 Batch [13400/25000], Train Loss: 0.7302
# 	 Batch [13600/25000], Train Loss: 0.7279
# 	 Batch [13800/25000], Train Loss: 0.7213
# 	 Batch [14000/25000], Train Loss: 0.8485
# 	 Batch [14200/25000], Train Loss: 0.8469
# 	 Batch [14400/25000], Train Loss: 0.7253
# 	 Batch [14600/25000], Train Loss: 0.7201
# 	 Batch [14800/25000], Train Loss: 0.8502
# 	 Batch [15000/25000], Train Loss: 0.7205
# 	 Batch [15200/25000], Train Loss: 0.8491
# 	 Batch [15400/25000], Train Loss: 0.8583
# 	 Batch [15600/25000], Train Loss: 0.7321
# 	 Batch [15800/25000], Train Loss: 0.8482
# 	 Batch [16000/25000], Train Loss: 0.7238
# 	 Batch [16200/25000], Train Loss: 0.9741
# 	 Batch [16400/25000], Train Loss: 0.6002
# 	 Batch [16600/25000], Train Loss: 0.8479
# 	 Batch [16800/25000], Train Loss: 0.4778
# 	 Batch [17000/25000], Train Loss: 0.8565
# 	 Batch [17200/25000], Train Loss: 0.9717
# 	 Batch [17400/25000], Train Loss: 0.8528
# 	 Batch [17600/25000], Train Loss: 0.7219
# 	 Batch [17800/25000], Train Loss: 0.9736
# 	 Batch [18000/25000], Train Loss: 0.8528
# 	 Batch [18200/25000], Train Loss: 0.5973
# 	 Batch [18400/25000], Train Loss: 0.8493
# 	 Batch [18600/25000], Train Loss: 0.7311
# 	 Batch [18800/25000], Train Loss: 0.9792
# 	 Batch [19000/25000], Train Loss: 0.7291
# 	 Batch [19200/25000], Train Loss: 0.7133
# 	 Batch [19400/25000], Train Loss: 0.7246
# 	 Batch [19600/25000], Train Loss: 0.7248
# 	 Batch [19800/25000], Train Loss: 0.4710
# 	 Batch [20000/25000], Train Loss: 0.7218
# 	 Batch [20200/25000], Train Loss: 0.7209
# 	 Batch [20400/25000], Train Loss: 0.8503
# 	 Batch [20600/25000], Train Loss: 0.7209
# 	 Batch [20800/25000], Train Loss: 0.8590
# 	 Batch [21000/25000], Train Loss: 0.8471
# 	 Batch [21200/25000], Train Loss: 0.8501
# 	 Batch [21400/25000], Train Loss: 0.9764
# 	 Batch [21600/25000], Train Loss: 0.8558
# 	 Batch [21800/25000], Train Loss: 0.5943
# 	 Batch [22000/25000], Train Loss: 0.7210
# 	 Batch [22200/25000], Train Loss: 0.8401
# 	 Batch [22400/25000], Train Loss: 0.5985
# 	 Batch [22600/25000], Train Loss: 0.7249
# 	 Batch [22800/25000], Train Loss: 0.7199
# 	 Batch [23000/25000], Train Loss: 0.7265
# 	 Batch [23200/25000], Train Loss: 0.8441
# 	 Batch [23400/25000], Train Loss: 0.5992
# 	 Batch [23600/25000], Train Loss: 0.8407
# 	 Batch [23800/25000], Train Loss: 0.7298
# 	 Batch [24000/25000], Train Loss: 0.5993
# 	 Batch [24200/25000], Train Loss: 0.6015
# 	 Batch [24400/25000], Train Loss: 0.9725
# 	 Batch [24600/25000], Train Loss: 0.8505
# 	 Batch [24800/25000], Train Loss: 0.8474
# Epoch [1/10], Validation Batch [0/250], Val Loss: 0.8511
# Epoch [1/10], Validation Batch [100/250], Val Loss: 0.8448
# Epoch [1/10], Validation Batch [200/250], Val Loss: 0.6024
# Best weight is saved at epoch 1
# Validation, Train Loss: 0.7857, Val Loss: 0.7905
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [2/10]:
# 	 Batch [0/25000], Train Loss: 0.8510
# 	 Batch [200/25000], Train Loss: 0.7314
# 	 Batch [400/25000], Train Loss: 0.8488
# 	 Batch [600/25000], Train Loss: 0.8528
# 	 Batch [800/25000], Train Loss: 0.7222
# 	 Batch [1000/25000], Train Loss: 0.7322
# 	 Batch [1200/25000], Train Loss: 0.9764
# 	 Batch [1400/25000], Train Loss: 0.7200
# 	 Batch [1600/25000], Train Loss: 0.7198
# 	 Batch [1800/25000], Train Loss: 0.8450
# 	 Batch [2000/25000], Train Loss: 0.9783
# 	 Batch [2200/25000], Train Loss: 0.8455
# 	 Batch [2400/25000], Train Loss: 0.7231
# 	 Batch [2600/25000], Train Loss: 0.9730
# 	 Batch [2800/25000], Train Loss: 0.5960
# 	 Batch [3000/25000], Train Loss: 0.8507
# 	 Batch [3200/25000], Train Loss: 0.9646
# 	 Batch [3400/25000], Train Loss: 0.4681
# 	 Batch [3600/25000], Train Loss: 0.9761
# 	 Batch [3800/25000], Train Loss: 0.6036
# 	 Batch [4000/25000], Train Loss: 0.8511
# 	 Batch [4200/25000], Train Loss: 0.9757
# 	 Batch [4400/25000], Train Loss: 0.8473
# 	 Batch [4600/25000], Train Loss: 0.9749
# 	 Batch [4800/25000], Train Loss: 0.9745
# 	 Batch [5000/25000], Train Loss: 0.5947
# 	 Batch [5200/25000], Train Loss: 0.8471
# 	 Batch [5400/25000], Train Loss: 0.7301
# 	 Batch [5600/25000], Train Loss: 0.6077
# 	 Batch [5800/25000], Train Loss: 0.8500
# 	 Batch [6000/25000], Train Loss: 0.7277
# 	 Batch [6200/25000], Train Loss: 0.7223
# 	 Batch [6400/25000], Train Loss: 0.8491
# 	 Batch [6600/25000], Train Loss: 0.9750
# 	 Batch [6800/25000], Train Loss: 0.7298
# 	 Batch [7000/25000], Train Loss: 0.5990
# 	 Batch [7200/25000], Train Loss: 0.9745
# 	 Batch [7400/25000], Train Loss: 0.7194
# 	 Batch [7600/25000], Train Loss: 0.8460
# 	 Batch [7800/25000], Train Loss: 0.8525
# 	 Batch [8000/25000], Train Loss: 0.7262
# 	 Batch [8200/25000], Train Loss: 0.7228
# 	 Batch [8400/25000], Train Loss: 0.8473
# 	 Batch [8600/25000], Train Loss: 0.7259
# 	 Batch [8800/25000], Train Loss: 0.7217
# 	 Batch [9000/25000], Train Loss: 0.8473
# 	 Batch [9200/25000], Train Loss: 0.8473
# 	 Batch [9400/25000], Train Loss: 0.4755
# 	 Batch [9600/25000], Train Loss: 0.8468
# 	 Batch [9800/25000], Train Loss: 0.7213
# 	 Batch [10000/25000], Train Loss: 0.8499
# 	 Batch [10200/25000], Train Loss: 0.5956
# 	 Batch [10400/25000], Train Loss: 0.8502
# 	 Batch [10600/25000], Train Loss: 0.8555
# 	 Batch [10800/25000], Train Loss: 0.5959
# 	 Batch [11000/25000], Train Loss: 0.7261
# 	 Batch [11200/25000], Train Loss: 0.9766
# 	 Batch [11400/25000], Train Loss: 0.8500
# 	 Batch [11600/25000], Train Loss: 0.8502
# 	 Batch [11800/25000], Train Loss: 0.5968
# 	 Batch [12000/25000], Train Loss: 0.9620
# 	 Batch [12200/25000], Train Loss: 0.8468
# 	 Batch [12400/25000], Train Loss: 0.7199
# 	 Batch [12600/25000], Train Loss: 0.7284
# 	 Batch [12800/25000], Train Loss: 0.9749
# 	 Batch [13000/25000], Train Loss: 0.8552
# 	 Batch [13200/25000], Train Loss: 0.9741
# 	 Batch [13400/25000], Train Loss: 0.7247
# 	 Batch [13600/25000], Train Loss: 0.7224
# 	 Batch [13800/25000], Train Loss: 0.5978
# 	 Batch [14000/25000], Train Loss: 0.8511
# 	 Batch [14200/25000], Train Loss: 0.8468
# 	 Batch [14400/25000], Train Loss: 0.5968
# 	 Batch [14600/25000], Train Loss: 0.8446
# 	 Batch [14800/25000], Train Loss: 0.8477
# 	 Batch [15000/25000], Train Loss: 0.8531
# 	 Batch [15200/25000], Train Loss: 0.9718
# 	 Batch [15400/25000], Train Loss: 0.8498
# 	 Batch [15600/25000], Train Loss: 0.9804
# 	 Batch [15800/25000], Train Loss: 0.8522
# 	 Batch [16000/25000], Train Loss: 0.7243
# 	 Batch [16200/25000], Train Loss: 0.9783
# 	 Batch [16400/25000], Train Loss: 0.6015
# 	 Batch [16600/25000], Train Loss: 0.4766
# 	 Batch [16800/25000], Train Loss: 0.8568
# 	 Batch [17000/25000], Train Loss: 0.9726
# 	 Batch [17200/25000], Train Loss: 0.9773
# 	 Batch [17400/25000], Train Loss: 0.7254
# 	 Batch [17600/25000], Train Loss: 0.8492
# 	 Batch [17800/25000], Train Loss: 0.8483
# 	 Batch [18000/25000], Train Loss: 0.8470
# 	 Batch [18200/25000], Train Loss: 0.6001
# 	 Batch [18400/25000], Train Loss: 0.7253
# 	 Batch [18600/25000], Train Loss: 0.8545
# 	 Batch [18800/25000], Train Loss: 0.8504
# 	 Batch [19000/25000], Train Loss: 0.7282
# 	 Batch [19200/25000], Train Loss: 0.9727
# 	 Batch [19400/25000], Train Loss: 0.8490
# 	 Batch [19600/25000], Train Loss: 0.7215
# 	 Batch [19800/25000], Train Loss: 0.9755
# 	 Batch [20000/25000], Train Loss: 0.7233
# 	 Batch [20200/25000], Train Loss: 0.7194
# 	 Batch [20400/25000], Train Loss: 0.7260
# 	 Batch [20600/25000], Train Loss: 0.9715
# 	 Batch [20800/25000], Train Loss: 0.8475
# 	 Batch [21000/25000], Train Loss: 0.7235
# 	 Batch [21200/25000], Train Loss: 0.7213
# 	 Batch [21400/25000], Train Loss: 0.8496
# 	 Batch [21600/25000], Train Loss: 0.8471
# 	 Batch [21800/25000], Train Loss: 0.9733
# 	 Batch [22000/25000], Train Loss: 0.8494
# 	 Batch [22200/25000], Train Loss: 0.9746
# 	 Batch [22400/25000], Train Loss: 0.8520
# 	 Batch [22600/25000], Train Loss: 0.8447
# 	 Batch [22800/25000], Train Loss: 0.7289
# 	 Batch [23000/25000], Train Loss: 0.8434
# 	 Batch [23200/25000], Train Loss: 0.7270
# 	 Batch [23400/25000], Train Loss: 0.7269
# 	 Batch [23600/25000], Train Loss: 0.9697
# 	 Batch [23800/25000], Train Loss: 0.7227
# 	 Batch [24000/25000], Train Loss: 0.8530
# 	 Batch [24200/25000], Train Loss: 0.7221
# 	 Batch [24400/25000], Train Loss: 0.9762
# 	 Batch [24600/25000], Train Loss: 0.7270
# 	 Batch [24800/25000], Train Loss: 0.8443
# Epoch [2/10], Validation Batch [0/250], Val Loss: 0.8499
# Epoch [2/10], Validation Batch [100/250], Val Loss: 0.8432
# Epoch [2/10], Validation Batch [200/250], Val Loss: 0.6023
# Best weight is saved at epoch 2
# Validation, Train Loss: 0.7856, Val Loss: 0.7905
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [3/10]:
# 	 Batch [0/25000], Train Loss: 0.8464
# 	 Batch [200/25000], Train Loss: 0.7233
# 	 Batch [400/25000], Train Loss: 0.8493
# 	 Batch [600/25000], Train Loss: 0.7183
# 	 Batch [800/25000], Train Loss: 0.8509
# 	 Batch [1000/25000], Train Loss: 0.7208
# 	 Batch [1200/25000], Train Loss: 0.7259
# 	 Batch [1400/25000], Train Loss: 0.9732
# 	 Batch [1600/25000], Train Loss: 0.6011
# 	 Batch [1800/25000], Train Loss: 0.9776
# 	 Batch [2000/25000], Train Loss: 0.7228
# 	 Batch [2200/25000], Train Loss: 0.7249
# 	 Batch [2400/25000], Train Loss: 0.7165
# 	 Batch [2600/25000], Train Loss: 0.9838
# 	 Batch [2800/25000], Train Loss: 0.8503
# 	 Batch [3000/25000], Train Loss: 0.8492
# 	 Batch [3200/25000], Train Loss: 0.8432
# 	 Batch [3400/25000], Train Loss: 0.7264
# 	 Batch [3600/25000], Train Loss: 0.7260
# 	 Batch [3800/25000], Train Loss: 0.9756
# 	 Batch [4000/25000], Train Loss: 0.9728
# 	 Batch [4200/25000], Train Loss: 0.7275
# 	 Batch [4400/25000], Train Loss: 0.8472
# 	 Batch [4600/25000], Train Loss: 0.7265
# 	 Batch [4800/25000], Train Loss: 0.8417
# 	 Batch [5000/25000], Train Loss: 0.9764
# 	 Batch [5200/25000], Train Loss: 0.9692
# 	 Batch [5400/25000], Train Loss: 0.7238
# 	 Batch [5600/25000], Train Loss: 0.8476
# 	 Batch [5800/25000], Train Loss: 0.7273
# 	 Batch [6000/25000], Train Loss: 0.5974
# 	 Batch [6200/25000], Train Loss: 0.7209
# 	 Batch [6400/25000], Train Loss: 0.7256
# 	 Batch [6600/25000], Train Loss: 0.8470
# 	 Batch [6800/25000], Train Loss: 0.8478
# 	 Batch [7000/25000], Train Loss: 0.7231
# 	 Batch [7200/25000], Train Loss: 0.8458
# 	 Batch [7400/25000], Train Loss: 0.8484
# 	 Batch [7600/25000], Train Loss: 0.8496
# 	 Batch [7800/25000], Train Loss: 0.7264
# 	 Batch [8000/25000], Train Loss: 0.8446
# 	 Batch [8200/25000], Train Loss: 0.8516
# 	 Batch [8400/25000], Train Loss: 0.8526
# 	 Batch [8600/25000], Train Loss: 0.7199
# 	 Batch [8800/25000], Train Loss: 0.7260
# 	 Batch [9000/25000], Train Loss: 0.7280
# 	 Batch [9200/25000], Train Loss: 0.7226
# 	 Batch [9400/25000], Train Loss: 0.7259
# 	 Batch [9600/25000], Train Loss: 0.7269
# 	 Batch [9800/25000], Train Loss: 0.8482
# 	 Batch [10000/25000], Train Loss: 0.8486
# 	 Batch [10200/25000], Train Loss: 0.5954
# 	 Batch [10400/25000], Train Loss: 0.7243
# 	 Batch [10600/25000], Train Loss: 0.8528
# 	 Batch [10800/25000], Train Loss: 0.7271
# 	 Batch [11000/25000], Train Loss: 0.8490
# 	 Batch [11200/25000], Train Loss: 0.7215
# 	 Batch [11400/25000], Train Loss: 0.7235
# 	 Batch [11600/25000], Train Loss: 0.6033
# 	 Batch [11800/25000], Train Loss: 0.8523
# 	 Batch [12000/25000], Train Loss: 0.7230
# 	 Batch [12200/25000], Train Loss: 0.5991
# 	 Batch [12400/25000], Train Loss: 0.7333
# 	 Batch [12600/25000], Train Loss: 0.7303
# 	 Batch [12800/25000], Train Loss: 0.8405
# 	 Batch [13000/25000], Train Loss: 0.9630
# 	 Batch [13200/25000], Train Loss: 0.8510
# 	 Batch [13400/25000], Train Loss: 0.8514
# 	 Batch [13600/25000], Train Loss: 0.7229
# 	 Batch [13800/25000], Train Loss: 0.9724
# 	 Batch [14000/25000], Train Loss: 0.8480
# 	 Batch [14200/25000], Train Loss: 0.8475
# 	 Batch [14400/25000], Train Loss: 0.5992
# 	 Batch [14600/25000], Train Loss: 0.7220
# 	 Batch [14800/25000], Train Loss: 0.8508
# 	 Batch [15000/25000], Train Loss: 0.7198
# 	 Batch [15200/25000], Train Loss: 0.9734
# 	 Batch [15400/25000], Train Loss: 0.8492
# 	 Batch [15600/25000], Train Loss: 0.8546
# 	 Batch [15800/25000], Train Loss: 0.8546
# 	 Batch [16000/25000], Train Loss: 0.8487
# 	 Batch [16200/25000], Train Loss: 0.7221
# 	 Batch [16400/25000], Train Loss: 0.9713
# 	 Batch [16600/25000], Train Loss: 0.7283
# 	 Batch [16800/25000], Train Loss: 0.9800
# 	 Batch [17000/25000], Train Loss: 0.7288
# 	 Batch [17200/25000], Train Loss: 0.9729
# 	 Batch [17400/25000], Train Loss: 0.7174
# 	 Batch [17600/25000], Train Loss: 0.9700
# 	 Batch [17800/25000], Train Loss: 0.5976
# 	 Batch [18000/25000], Train Loss: 0.9772
# 	 Batch [18200/25000], Train Loss: 0.7226
# 	 Batch [18400/25000], Train Loss: 0.7300
# 	 Batch [18600/25000], Train Loss: 0.7254
# 	 Batch [18800/25000], Train Loss: 0.8477
# 	 Batch [19000/25000], Train Loss: 0.7218
# 	 Batch [19200/25000], Train Loss: 0.5982
# 	 Batch [19400/25000], Train Loss: 0.7280
# 	 Batch [19600/25000], Train Loss: 0.8526
# 	 Batch [19800/25000], Train Loss: 0.8497
# 	 Batch [20000/25000], Train Loss: 0.8474
# 	 Batch [20200/25000], Train Loss: 0.5964
# 	 Batch [20400/25000], Train Loss: 0.8545
# 	 Batch [20600/25000], Train Loss: 0.7280
# 	 Batch [20800/25000], Train Loss: 0.8507
# 	 Batch [21000/25000], Train Loss: 0.5932
# 	 Batch [21200/25000], Train Loss: 0.8461
# 	 Batch [21400/25000], Train Loss: 0.7267
# 	 Batch [21600/25000], Train Loss: 0.8462
# 	 Batch [21800/25000], Train Loss: 0.7238
# 	 Batch [22000/25000], Train Loss: 0.5965
# 	 Batch [22200/25000], Train Loss: 0.8571
# 	 Batch [22400/25000], Train Loss: 0.8491
# 	 Batch [22600/25000], Train Loss: 0.8493
# 	 Batch [22800/25000], Train Loss: 0.8513
# 	 Batch [23000/25000], Train Loss: 0.8511
# 	 Batch [23200/25000], Train Loss: 0.8510
# 	 Batch [23400/25000], Train Loss: 0.9763
# 	 Batch [23600/25000], Train Loss: 0.7173
# 	 Batch [23800/25000], Train Loss: 0.8554
# 	 Batch [24000/25000], Train Loss: 0.5949
# 	 Batch [24200/25000], Train Loss: 0.9707
# 	 Batch [24400/25000], Train Loss: 0.8414
# 	 Batch [24600/25000], Train Loss: 0.8523
# 	 Batch [24800/25000], Train Loss: 0.8473
# Epoch [3/10], Validation Batch [0/250], Val Loss: 0.8467
# Epoch [3/10], Validation Batch [100/250], Val Loss: 0.8413
# Epoch [3/10], Validation Batch [200/250], Val Loss: 0.6008
# Best weight is saved at epoch 3
# Validation, Train Loss: 0.7856, Val Loss: 0.7903
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [4/10]:
# 	 Batch [0/25000], Train Loss: 0.8491
# 	 Batch [200/25000], Train Loss: 0.8496
# 	 Batch [400/25000], Train Loss: 0.6014
# 	 Batch [600/25000], Train Loss: 0.7137
# 	 Batch [800/25000], Train Loss: 0.8429
# 	 Batch [1000/25000], Train Loss: 0.8451
# 	 Batch [1200/25000], Train Loss: 0.8583
# 	 Batch [1400/25000], Train Loss: 0.4746
# 	 Batch [1600/25000], Train Loss: 0.7295
# 	 Batch [1800/25000], Train Loss: 0.8480
# 	 Batch [2000/25000], Train Loss: 0.5956
# 	 Batch [2200/25000], Train Loss: 0.4732
# 	 Batch [2400/25000], Train Loss: 0.8570
# 	 Batch [2600/25000], Train Loss: 0.4719
# 	 Batch [2800/25000], Train Loss: 0.9757
# 	 Batch [3000/25000], Train Loss: 0.8427
# 	 Batch [3200/25000], Train Loss: 0.7317
# 	 Batch [3400/25000], Train Loss: 0.9786
# 	 Batch [3600/25000], Train Loss: 0.8544
# 	 Batch [3800/25000], Train Loss: 0.8447
# 	 Batch [4000/25000], Train Loss: 0.9728
# 	 Batch [4200/25000], Train Loss: 0.7230
# 	 Batch [4400/25000], Train Loss: 0.8460
# 	 Batch [4600/25000], Train Loss: 0.8469
# 	 Batch [4800/25000], Train Loss: 0.9693
# 	 Batch [5000/25000], Train Loss: 0.7243
# 	 Batch [5200/25000], Train Loss: 0.6034
# 	 Batch [5400/25000], Train Loss: 0.8484
# 	 Batch [5600/25000], Train Loss: 0.8557
# 	 Batch [5800/25000], Train Loss: 0.7150
# 	 Batch [6000/25000], Train Loss: 0.7286
# 	 Batch [6200/25000], Train Loss: 0.8453
# 	 Batch [6400/25000], Train Loss: 0.8445
# 	 Batch [6600/25000], Train Loss: 0.7212
# 	 Batch [6800/25000], Train Loss: 0.7139
# 	 Batch [7000/25000], Train Loss: 0.8440
# 	 Batch [7200/25000], Train Loss: 0.7288
# 	 Batch [7400/25000], Train Loss: 0.7258
# 	 Batch [7600/25000], Train Loss: 0.7295
# 	 Batch [7800/25000], Train Loss: 0.8503
# 	 Batch [8000/25000], Train Loss: 0.5995
# 	 Batch [8200/25000], Train Loss: 0.7220
# 	 Batch [8400/25000], Train Loss: 0.9698
# 	 Batch [8600/25000], Train Loss: 0.9728
# 	 Batch [8800/25000], Train Loss: 0.5976
# 	 Batch [9000/25000], Train Loss: 0.8474
# 	 Batch [9200/25000], Train Loss: 0.5925
# 	 Batch [9400/25000], Train Loss: 0.8513
# 	 Batch [9600/25000], Train Loss: 0.8479
# 	 Batch [9800/25000], Train Loss: 0.7231
# 	 Batch [10000/25000], Train Loss: 0.7253
# 	 Batch [10200/25000], Train Loss: 0.9694
# 	 Batch [10400/25000], Train Loss: 0.9752
# 	 Batch [10600/25000], Train Loss: 0.8570
# 	 Batch [10800/25000], Train Loss: 0.8554
# 	 Batch [11000/25000], Train Loss: 0.7184
# 	 Batch [11200/25000], Train Loss: 0.9774
# 	 Batch [11400/25000], Train Loss: 0.8538
# 	 Batch [11600/25000], Train Loss: 0.8446
# 	 Batch [11800/25000], Train Loss: 0.8438
# 	 Batch [12000/25000], Train Loss: 0.8517
# 	 Batch [12200/25000], Train Loss: 0.8475
# 	 Batch [12400/25000], Train Loss: 0.8439
# 	 Batch [12600/25000], Train Loss: 0.7279
# 	 Batch [12800/25000], Train Loss: 0.8499
# 	 Batch [13000/25000], Train Loss: 0.7277
# 	 Batch [13200/25000], Train Loss: 0.9739
# 	 Batch [13400/25000], Train Loss: 0.8459
# 	 Batch [13600/25000], Train Loss: 0.8594
# 	 Batch [13800/25000], Train Loss: 0.8426
# 	 Batch [14000/25000], Train Loss: 0.9764
# 	 Batch [14200/25000], Train Loss: 0.7210
# 	 Batch [14400/25000], Train Loss: 0.8483
# 	 Batch [14600/25000], Train Loss: 0.8560
# 	 Batch [14800/25000], Train Loss: 0.8412
# 	 Batch [15000/25000], Train Loss: 0.7194
# 	 Batch [15200/25000], Train Loss: 0.7247
# 	 Batch [15400/25000], Train Loss: 0.7195
# 	 Batch [15600/25000], Train Loss: 0.7265
# 	 Batch [15800/25000], Train Loss: 0.6033
# 	 Batch [16000/25000], Train Loss: 0.8567
# 	 Batch [16200/25000], Train Loss: 0.5994
# 	 Batch [16400/25000], Train Loss: 0.8454
# 	 Batch [16600/25000], Train Loss: 0.5940
# 	 Batch [16800/25000], Train Loss: 0.9704
# 	 Batch [17000/25000], Train Loss: 0.8462
# 	 Batch [17200/25000], Train Loss: 0.7233
# 	 Batch [17400/25000], Train Loss: 0.8581
# 	 Batch [17600/25000], Train Loss: 0.9723
# 	 Batch [17800/25000], Train Loss: 0.6052
# 	 Batch [18000/25000], Train Loss: 0.6041
# 	 Batch [18200/25000], Train Loss: 0.8363
# 	 Batch [18400/25000], Train Loss: 0.8572
# 	 Batch [18600/25000], Train Loss: 0.8339
# 	 Batch [18800/25000], Train Loss: 0.7312
# 	 Batch [19000/25000], Train Loss: 0.7268
# 	 Batch [19200/25000], Train Loss: 0.4716
# 	 Batch [19400/25000], Train Loss: 0.7155
# 	 Batch [19600/25000], Train Loss: 0.9700
# 	 Batch [19800/25000], Train Loss: 0.5989
# 	 Batch [20000/25000], Train Loss: 0.7187
# 	 Batch [20200/25000], Train Loss: 0.8532
# 	 Batch [20400/25000], Train Loss: 0.8439
# 	 Batch [20600/25000], Train Loss: 0.9772
# 	 Batch [20800/25000], Train Loss: 0.8560
# 	 Batch [21000/25000], Train Loss: 0.9677
# 	 Batch [21200/25000], Train Loss: 0.8509
# 	 Batch [21400/25000], Train Loss: 0.9739
# 	 Batch [21600/25000], Train Loss: 0.7320
# 	 Batch [21800/25000], Train Loss: 0.5891
# 	 Batch [22000/25000], Train Loss: 0.7322
# 	 Batch [22200/25000], Train Loss: 0.9771
# 	 Batch [22400/25000], Train Loss: 0.8531
# 	 Batch [22600/25000], Train Loss: 0.7208
# 	 Batch [22800/25000], Train Loss: 0.7275
# 	 Batch [23000/25000], Train Loss: 0.7242
# 	 Batch [23200/25000], Train Loss: 0.9780
# 	 Batch [23400/25000], Train Loss: 0.7218
# 	 Batch [23600/25000], Train Loss: 0.7306
# 	 Batch [23800/25000], Train Loss: 0.7263
# 	 Batch [24000/25000], Train Loss: 0.7250
# 	 Batch [24200/25000], Train Loss: 0.6065
# 	 Batch [24400/25000], Train Loss: 0.4729
# 	 Batch [24600/25000], Train Loss: 0.8492
# 	 Batch [24800/25000], Train Loss: 0.8393
# Epoch [4/10], Validation Batch [0/250], Val Loss: 0.8454
# Epoch [4/10], Validation Batch [100/250], Val Loss: 0.8385
# Epoch [4/10], Validation Batch [200/250], Val Loss: 0.6006
# Best weight is saved at epoch 4
# Validation, Train Loss: 0.7856, Val Loss: 0.7903
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [5/10]:
# 	 Batch [0/25000], Train Loss: 0.8538
# 	 Batch [200/25000], Train Loss: 0.7208
# 	 Batch [400/25000], Train Loss: 0.7221
# 	 Batch [600/25000], Train Loss: 0.8498
# 	 Batch [800/25000], Train Loss: 0.6053
# 	 Batch [1000/25000], Train Loss: 0.7253
# 	 Batch [1200/25000], Train Loss: 0.8438
# 	 Batch [1400/25000], Train Loss: 0.5936
# 	 Batch [1600/25000], Train Loss: 0.7204
# 	 Batch [1800/25000], Train Loss: 0.5926
# 	 Batch [2000/25000], Train Loss: 0.9698
# 	 Batch [2200/25000], Train Loss: 0.7174
# 	 Batch [2400/25000], Train Loss: 0.7352
# 	 Batch [2600/25000], Train Loss: 0.9799
# 	 Batch [2800/25000], Train Loss: 0.8452
# 	 Batch [3000/25000], Train Loss: 0.9733
# 	 Batch [3200/25000], Train Loss: 0.7259
# 	 Batch [3400/25000], Train Loss: 0.8529
# 	 Batch [3600/25000], Train Loss: 0.8587
# 	 Batch [3800/25000], Train Loss: 0.7179
# 	 Batch [4000/25000], Train Loss: 0.7257
# 	 Batch [4200/25000], Train Loss: 0.8514
# 	 Batch [4400/25000], Train Loss: 0.7317
# 	 Batch [4600/25000], Train Loss: 0.8569
# 	 Batch [4800/25000], Train Loss: 0.7194
# 	 Batch [5000/25000], Train Loss: 0.8533
# 	 Batch [5200/25000], Train Loss: 0.8503
# 	 Batch [5400/25000], Train Loss: 0.9820
# 	 Batch [5600/25000], Train Loss: 0.7184
# 	 Batch [5800/25000], Train Loss: 0.8377
# 	 Batch [6000/25000], Train Loss: 0.7273
# 	 Batch [6200/25000], Train Loss: 0.8564
# 	 Batch [6400/25000], Train Loss: 0.8533
# 	 Batch [6600/25000], Train Loss: 0.4797
# 	 Batch [6800/25000], Train Loss: 0.7314
# 	 Batch [7000/25000], Train Loss: 0.7227
# 	 Batch [7200/25000], Train Loss: 0.9769
# 	 Batch [7400/25000], Train Loss: 0.7259
# 	 Batch [7600/25000], Train Loss: 0.8433
# 	 Batch [7800/25000], Train Loss: 0.8519
# 	 Batch [8000/25000], Train Loss: 0.7167
# 	 Batch [8200/25000], Train Loss: 0.9717
# 	 Batch [8400/25000], Train Loss: 0.7140
# 	 Batch [8600/25000], Train Loss: 0.5892
# 	 Batch [8800/25000], Train Loss: 0.8480
# 	 Batch [9000/25000], Train Loss: 0.5926
# 	 Batch [9200/25000], Train Loss: 0.8521
# 	 Batch [9400/25000], Train Loss: 0.5960
# 	 Batch [9600/25000], Train Loss: 0.7247
# 	 Batch [9800/25000], Train Loss: 0.8550
# 	 Batch [10000/25000], Train Loss: 0.7191
# 	 Batch [10200/25000], Train Loss: 0.8401
# 	 Batch [10400/25000], Train Loss: 0.9765
# 	 Batch [10600/25000], Train Loss: 0.5999
# 	 Batch [10800/25000], Train Loss: 0.8554
# 	 Batch [11000/25000], Train Loss: 0.8484
# 	 Batch [11200/25000], Train Loss: 0.9700
# 	 Batch [11400/25000], Train Loss: 0.8459
# 	 Batch [11600/25000], Train Loss: 0.7265
# 	 Batch [11800/25000], Train Loss: 0.7330
# 	 Batch [12000/25000], Train Loss: 0.8400
# 	 Batch [12200/25000], Train Loss: 0.7284
# 	 Batch [12400/25000], Train Loss: 0.5988
# 	 Batch [12600/25000], Train Loss: 0.8508
# 	 Batch [12800/25000], Train Loss: 0.7277
# 	 Batch [13000/25000], Train Loss: 0.9749
# 	 Batch [13200/25000], Train Loss: 0.8518
# 	 Batch [13400/25000], Train Loss: 0.7409
# 	 Batch [13600/25000], Train Loss: 0.8481
# 	 Batch [13800/25000], Train Loss: 0.6182
# 	 Batch [14000/25000], Train Loss: 0.7228
# 	 Batch [14200/25000], Train Loss: 0.9710
# 	 Batch [14400/25000], Train Loss: 0.7420
# 	 Batch [14600/25000], Train Loss: 0.7198
# 	 Batch [14800/25000], Train Loss: 0.7275
# 	 Batch [15000/25000], Train Loss: 0.8424
# 	 Batch [15200/25000], Train Loss: 0.5980
# 	 Batch [15400/25000], Train Loss: 0.8477
# 	 Batch [15600/25000], Train Loss: 0.8526
# 	 Batch [15800/25000], Train Loss: 0.8452
# 	 Batch [16000/25000], Train Loss: 0.8522
# 	 Batch [16200/25000], Train Loss: 0.8488
# 	 Batch [16400/25000], Train Loss: 0.8375
# 	 Batch [16600/25000], Train Loss: 0.8529
# 	 Batch [16800/25000], Train Loss: 0.9707
# 	 Batch [17000/25000], Train Loss: 0.5993
# 	 Batch [17200/25000], Train Loss: 0.9718
# 	 Batch [17400/25000], Train Loss: 0.7302
# 	 Batch [17600/25000], Train Loss: 0.7293
# 	 Batch [17800/25000], Train Loss: 0.7181
# 	 Batch [18000/25000], Train Loss: 0.7183
# 	 Batch [18200/25000], Train Loss: 0.8502
# 	 Batch [18400/25000], Train Loss: 0.9871
# 	 Batch [18600/25000], Train Loss: 0.5933
# 	 Batch [18800/25000], Train Loss: 0.7198
# 	 Batch [19000/25000], Train Loss: 0.5967
# 	 Batch [19200/25000], Train Loss: 0.9725
# 	 Batch [19400/25000], Train Loss: 0.7225
# 	 Batch [19600/25000], Train Loss: 0.7175
# 	 Batch [19800/25000], Train Loss: 0.8416
# 	 Batch [20000/25000], Train Loss: 0.9786
# 	 Batch [20200/25000], Train Loss: 0.7277
# 	 Batch [20400/25000], Train Loss: 0.5931
# 	 Batch [20600/25000], Train Loss: 0.7142
# 	 Batch [20800/25000], Train Loss: 0.8500
# 	 Batch [21000/25000], Train Loss: 0.6116
# 	 Batch [21200/25000], Train Loss: 0.7249
# 	 Batch [21400/25000], Train Loss: 0.9671
# 	 Batch [21600/25000], Train Loss: 0.8477
# 	 Batch [21800/25000], Train Loss: 0.7217
# 	 Batch [22000/25000], Train Loss: 0.8510
# 	 Batch [22200/25000], Train Loss: 0.9762
# 	 Batch [22400/25000], Train Loss: 0.7319
# 	 Batch [22600/25000], Train Loss: 0.7313
# 	 Batch [22800/25000], Train Loss: 0.8396
# 	 Batch [23000/25000], Train Loss: 0.9748
# 	 Batch [23200/25000], Train Loss: 0.8526
# 	 Batch [23400/25000], Train Loss: 0.7218
# 	 Batch [23600/25000], Train Loss: 0.8467
# 	 Batch [23800/25000], Train Loss: 0.8538
# 	 Batch [24000/25000], Train Loss: 0.9765
# 	 Batch [24200/25000], Train Loss: 0.6059
# 	 Batch [24400/25000], Train Loss: 0.7276
# 	 Batch [24600/25000], Train Loss: 0.8431
# 	 Batch [24800/25000], Train Loss: 0.8561
# Epoch [5/10], Validation Batch [0/250], Val Loss: 0.8395
# Epoch [5/10], Validation Batch [100/250], Val Loss: 0.8402
# Epoch [5/10], Validation Batch [200/250], Val Loss: 0.5964
# Validation, Train Loss: 0.7856, Val Loss: 0.7903
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [6/10]:
# 	 Batch [0/25000], Train Loss: 0.6022
# 	 Batch [200/25000], Train Loss: 0.8446
# 	 Batch [400/25000], Train Loss: 0.7160
# 	 Batch [600/25000], Train Loss: 0.8565
# 	 Batch [800/25000], Train Loss: 0.7291
# 	 Batch [1000/25000], Train Loss: 0.7209
# 	 Batch [1200/25000], Train Loss: 0.9771
# 	 Batch [1400/25000], Train Loss: 0.8579
# 	 Batch [1600/25000], Train Loss: 0.8587
# 	 Batch [1800/25000], Train Loss: 0.9793
# 	 Batch [2000/25000], Train Loss: 0.8432
# 	 Batch [2200/25000], Train Loss: 0.7235
# 	 Batch [2400/25000], Train Loss: 0.9799
# 	 Batch [2600/25000], Train Loss: 0.7126
# 	 Batch [2800/25000], Train Loss: 0.7198
# 	 Batch [3000/25000], Train Loss: 0.8513
# 	 Batch [3200/25000], Train Loss: 0.5992
# 	 Batch [3400/25000], Train Loss: 0.9772
# 	 Batch [3600/25000], Train Loss: 0.4749
# 	 Batch [3800/25000], Train Loss: 0.8450
# 	 Batch [4000/25000], Train Loss: 0.8600
# 	 Batch [4200/25000], Train Loss: 0.7232
# 	 Batch [4400/25000], Train Loss: 0.7158
# 	 Batch [4600/25000], Train Loss: 0.8506
# 	 Batch [4800/25000], Train Loss: 0.7123
# 	 Batch [5000/25000], Train Loss: 0.7227
# 	 Batch [5200/25000], Train Loss: 0.8559
# 	 Batch [5400/25000], Train Loss: 0.8488
# 	 Batch [5600/25000], Train Loss: 0.9764
# 	 Batch [5800/25000], Train Loss: 0.7291
# 	 Batch [6000/25000], Train Loss: 0.7244
# 	 Batch [6200/25000], Train Loss: 0.8563
# 	 Batch [6400/25000], Train Loss: 0.8520
# 	 Batch [6600/25000], Train Loss: 0.7252
# 	 Batch [6800/25000], Train Loss: 0.9670
# 	 Batch [7000/25000], Train Loss: 0.9773
# 	 Batch [7200/25000], Train Loss: 0.8453
# 	 Batch [7400/25000], Train Loss: 0.7098
# 	 Batch [7600/25000], Train Loss: 0.7382
# 	 Batch [7800/25000], Train Loss: 0.8401
# 	 Batch [8000/25000], Train Loss: 0.8405
# 	 Batch [8200/25000], Train Loss: 0.8358
# 	 Batch [8400/25000], Train Loss: 0.6074
# 	 Batch [8600/25000], Train Loss: 0.7099
# 	 Batch [8800/25000], Train Loss: 0.8552
# 	 Batch [9000/25000], Train Loss: 0.7295
# 	 Batch [9200/25000], Train Loss: 0.7276
# 	 Batch [9400/25000], Train Loss: 0.7401
# 	 Batch [9600/25000], Train Loss: 0.9798
# 	 Batch [9800/25000], Train Loss: 0.7310
# 	 Batch [10000/25000], Train Loss: 0.8457
# 	 Batch [10200/25000], Train Loss: 0.8444
# 	 Batch [10400/25000], Train Loss: 0.9711
# 	 Batch [10600/25000], Train Loss: 0.8351
# 	 Batch [10800/25000], Train Loss: 0.8522
# 	 Batch [11000/25000], Train Loss: 0.9716
# 	 Batch [11200/25000], Train Loss: 0.8626
# 	 Batch [11400/25000], Train Loss: 0.7205
# 	 Batch [11600/25000], Train Loss: 0.7308
# 	 Batch [11800/25000], Train Loss: 0.9770
# 	 Batch [12000/25000], Train Loss: 0.8605
# 	 Batch [12200/25000], Train Loss: 0.7232
# 	 Batch [12400/25000], Train Loss: 0.7114
# 	 Batch [12600/25000], Train Loss: 0.9752
# 	 Batch [12800/25000], Train Loss: 0.8379
# 	 Batch [13000/25000], Train Loss: 0.9688
# 	 Batch [13200/25000], Train Loss: 0.8508
# 	 Batch [13400/25000], Train Loss: 0.7172
# 	 Batch [13600/25000], Train Loss: 0.8488
# 	 Batch [13800/25000], Train Loss: 0.7239
# 	 Batch [14000/25000], Train Loss: 0.7276
# 	 Batch [14200/25000], Train Loss: 0.8425
# 	 Batch [14400/25000], Train Loss: 0.6005
# 	 Batch [14600/25000], Train Loss: 0.9669
# 	 Batch [14800/25000], Train Loss: 0.5975
# 	 Batch [15000/25000], Train Loss: 0.8533
# 	 Batch [15200/25000], Train Loss: 0.7224
# 	 Batch [15400/25000], Train Loss: 0.5985
# 	 Batch [15600/25000], Train Loss: 0.7161
# 	 Batch [15800/25000], Train Loss: 0.6020
# 	 Batch [16000/25000], Train Loss: 0.7227
# 	 Batch [16200/25000], Train Loss: 0.8495
# 	 Batch [16400/25000], Train Loss: 0.7291
# 	 Batch [16600/25000], Train Loss: 0.5911
# 	 Batch [16800/25000], Train Loss: 0.9751
# 	 Batch [17000/25000], Train Loss: 0.7332
# 	 Batch [17200/25000], Train Loss: 0.7257
# 	 Batch [17400/25000], Train Loss: 0.7279
# 	 Batch [17600/25000], Train Loss: 0.7206
# 	 Batch [17800/25000], Train Loss: 0.8415
# 	 Batch [18000/25000], Train Loss: 0.7296
# 	 Batch [18200/25000], Train Loss: 0.7256
# 	 Batch [18400/25000], Train Loss: 0.7183
# 	 Batch [18600/25000], Train Loss: 0.8451
# 	 Batch [18800/25000], Train Loss: 0.8471
# 	 Batch [19000/25000], Train Loss: 0.5961
# 	 Batch [19200/25000], Train Loss: 0.8496
# 	 Batch [19400/25000], Train Loss: 0.7235
# 	 Batch [19600/25000], Train Loss: 0.9716
# 	 Batch [19800/25000], Train Loss: 0.8553
# 	 Batch [20000/25000], Train Loss: 0.8347
# 	 Batch [20200/25000], Train Loss: 0.7244
# 	 Batch [20400/25000], Train Loss: 0.9820
# 	 Batch [20600/25000], Train Loss: 0.7156
# 	 Batch [20800/25000], Train Loss: 0.7312
# 	 Batch [21000/25000], Train Loss: 0.9711
# 	 Batch [21200/25000], Train Loss: 0.5915
# 	 Batch [21400/25000], Train Loss: 0.7209
# 	 Batch [21600/25000], Train Loss: 0.8510
# 	 Batch [21800/25000], Train Loss: 0.8484
# 	 Batch [22000/25000], Train Loss: 0.7307
# 	 Batch [22200/25000], Train Loss: 0.8376
# 	 Batch [22400/25000], Train Loss: 0.9800
# 	 Batch [22600/25000], Train Loss: 0.7228
# 	 Batch [22800/25000], Train Loss: 0.8384
# 	 Batch [23000/25000], Train Loss: 0.7257
# 	 Batch [23200/25000], Train Loss: 0.7244
# 	 Batch [23400/25000], Train Loss: 0.8538
# 	 Batch [23600/25000], Train Loss: 0.7273
# 	 Batch [23800/25000], Train Loss: 0.8525
# 	 Batch [24000/25000], Train Loss: 0.7224
# 	 Batch [24200/25000], Train Loss: 0.7300
# 	 Batch [24400/25000], Train Loss: 0.9713
# 	 Batch [24600/25000], Train Loss: 0.8383
# 	 Batch [24800/25000], Train Loss: 0.9762
# Epoch [6/10], Validation Batch [0/250], Val Loss: 0.8420
# Epoch [6/10], Validation Batch [100/250], Val Loss: 0.8402
# Epoch [6/10], Validation Batch [200/250], Val Loss: 0.5974
# Best weight is saved at epoch 6
# Validation, Train Loss: 0.7856, Val Loss: 0.7902
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [7/10]:
# 	 Batch [0/25000], Train Loss: 0.7263
# 	 Batch [200/25000], Train Loss: 0.8488
# 	 Batch [400/25000], Train Loss: 0.6058
# 	 Batch [600/25000], Train Loss: 0.9724
# 	 Batch [800/25000], Train Loss: 0.8542
# 	 Batch [1000/25000], Train Loss: 0.7221
# 	 Batch [1200/25000], Train Loss: 0.8590
# 	 Batch [1400/25000], Train Loss: 0.9682
# 	 Batch [1600/25000], Train Loss: 0.9770
# 	 Batch [1800/25000], Train Loss: 0.7180
# 	 Batch [2000/25000], Train Loss: 0.9766
# 	 Batch [2200/25000], Train Loss: 0.7223
# 	 Batch [2400/25000], Train Loss: 0.8450
# 	 Batch [2600/25000], Train Loss: 0.5910
# 	 Batch [2800/25000], Train Loss: 0.8571
# 	 Batch [3000/25000], Train Loss: 0.8515
# 	 Batch [3200/25000], Train Loss: 0.7473
# 	 Batch [3400/25000], Train Loss: 0.7342
# 	 Batch [3600/25000], Train Loss: 0.7207
# 	 Batch [3800/25000], Train Loss: 0.6014
# 	 Batch [4000/25000], Train Loss: 0.9726
# 	 Batch [4200/25000], Train Loss: 0.8424
# 	 Batch [4400/25000], Train Loss: 0.7371
# 	 Batch [4600/25000], Train Loss: 0.8510
# 	 Batch [4800/25000], Train Loss: 0.9783
# 	 Batch [5000/25000], Train Loss: 0.8464
# 	 Batch [5200/25000], Train Loss: 0.7188
# 	 Batch [5400/25000], Train Loss: 0.7156
# 	 Batch [5600/25000], Train Loss: 0.9749
# 	 Batch [5800/25000], Train Loss: 0.5936
# 	 Batch [6000/25000], Train Loss: 0.6039
# 	 Batch [6200/25000], Train Loss: 0.8595
# 	 Batch [6400/25000], Train Loss: 0.9753
# 	 Batch [6600/25000], Train Loss: 0.9654
# 	 Batch [6800/25000], Train Loss: 0.9605
# 	 Batch [7000/25000], Train Loss: 0.5933
# 	 Batch [7200/25000], Train Loss: 0.9747
# 	 Batch [7400/25000], Train Loss: 0.7286
# 	 Batch [7600/25000], Train Loss: 0.8522
# 	 Batch [7800/25000], Train Loss: 0.8501
# 	 Batch [8000/25000], Train Loss: 0.8533
# 	 Batch [8200/25000], Train Loss: 0.9747
# 	 Batch [8400/25000], Train Loss: 0.7271
# 	 Batch [8600/25000], Train Loss: 0.9762
# 	 Batch [8800/25000], Train Loss: 0.7372
# 	 Batch [9000/25000], Train Loss: 0.9739
# 	 Batch [9200/25000], Train Loss: 0.8516
# 	 Batch [9400/25000], Train Loss: 0.8470
# 	 Batch [9600/25000], Train Loss: 0.7147
# 	 Batch [9800/25000], Train Loss: 0.7290
# 	 Batch [10000/25000], Train Loss: 0.7099
# 	 Batch [10200/25000], Train Loss: 0.8589
# 	 Batch [10400/25000], Train Loss: 0.5939
# 	 Batch [10600/25000], Train Loss: 0.9776
# 	 Batch [10800/25000], Train Loss: 0.6073
# 	 Batch [11000/25000], Train Loss: 0.9704
# 	 Batch [11200/25000], Train Loss: 0.8538
# 	 Batch [11400/25000], Train Loss: 0.9760
# 	 Batch [11600/25000], Train Loss: 0.9981
# 	 Batch [11800/25000], Train Loss: 0.8549
# 	 Batch [12000/25000], Train Loss: 0.5999
# 	 Batch [12200/25000], Train Loss: 0.7135
# 	 Batch [12400/25000], Train Loss: 0.8466
# 	 Batch [12600/25000], Train Loss: 0.8532
# 	 Batch [12800/25000], Train Loss: 0.8494
# 	 Batch [13000/25000], Train Loss: 0.9717
# 	 Batch [13200/25000], Train Loss: 0.9679
# 	 Batch [13400/25000], Train Loss: 0.8381
# 	 Batch [13600/25000], Train Loss: 0.7303
# 	 Batch [13800/25000], Train Loss: 0.8403
# 	 Batch [14000/25000], Train Loss: 0.7321
# 	 Batch [14200/25000], Train Loss: 0.8333
# 	 Batch [14400/25000], Train Loss: 0.9717
# 	 Batch [14600/25000], Train Loss: 0.9824
# 	 Batch [14800/25000], Train Loss: 0.7285
# 	 Batch [15000/25000], Train Loss: 0.8477
# 	 Batch [15200/25000], Train Loss: 0.9760
# 	 Batch [15400/25000], Train Loss: 0.7373
# 	 Batch [15600/25000], Train Loss: 0.8490
# 	 Batch [15800/25000], Train Loss: 0.4784
# 	 Batch [16000/25000], Train Loss: 0.8550
# 	 Batch [16200/25000], Train Loss: 0.7288
# 	 Batch [16400/25000], Train Loss: 0.9863
# 	 Batch [16600/25000], Train Loss: 0.7223
# 	 Batch [16800/25000], Train Loss: 0.8480
# 	 Batch [17000/25000], Train Loss: 0.9777
# 	 Batch [17200/25000], Train Loss: 0.9828
# 	 Batch [17400/25000], Train Loss: 0.7428
# 	 Batch [17600/25000], Train Loss: 0.8520
# 	 Batch [17800/25000], Train Loss: 0.7073
# 	 Batch [18000/25000], Train Loss: 0.8425
# 	 Batch [18200/25000], Train Loss: 0.8485
# 	 Batch [18400/25000], Train Loss: 0.8420
# 	 Batch [18600/25000], Train Loss: 0.7234
# 	 Batch [18800/25000], Train Loss: 0.8352
# 	 Batch [19000/25000], Train Loss: 0.5987
# 	 Batch [19200/25000], Train Loss: 0.7238
# 	 Batch [19400/25000], Train Loss: 0.7252
# 	 Batch [19600/25000], Train Loss: 0.5991
# 	 Batch [19800/25000], Train Loss: 0.8618
# 	 Batch [20000/25000], Train Loss: 0.7058
# 	 Batch [20200/25000], Train Loss: 0.9820
# 	 Batch [20400/25000], Train Loss: 0.8541
# 	 Batch [20600/25000], Train Loss: 0.8444
# 	 Batch [20800/25000], Train Loss: 0.6071
# 	 Batch [21000/25000], Train Loss: 0.5954
# 	 Batch [21200/25000], Train Loss: 0.8412
# 	 Batch [21400/25000], Train Loss: 0.5987
# 	 Batch [21600/25000], Train Loss: 0.8576
# 	 Batch [21800/25000], Train Loss: 0.8406
# 	 Batch [22000/25000], Train Loss: 0.9721
# 	 Batch [22200/25000], Train Loss: 0.8541
# 	 Batch [22400/25000], Train Loss: 0.9796
# 	 Batch [22600/25000], Train Loss: 0.5941
# 	 Batch [22800/25000], Train Loss: 0.7316
# 	 Batch [23000/25000], Train Loss: 0.9657
# 	 Batch [23200/25000], Train Loss: 0.6076
# 	 Batch [23400/25000], Train Loss: 0.9731
# 	 Batch [23600/25000], Train Loss: 0.9768
# 	 Batch [23800/25000], Train Loss: 0.7382
# 	 Batch [24000/25000], Train Loss: 0.7297
# 	 Batch [24200/25000], Train Loss: 0.7236
# 	 Batch [24400/25000], Train Loss: 0.7287
# 	 Batch [24600/25000], Train Loss: 0.4763
# 	 Batch [24800/25000], Train Loss: 0.9824
# Epoch [7/10], Validation Batch [0/250], Val Loss: 0.8491
# Epoch [7/10], Validation Batch [100/250], Val Loss: 0.8409
# Epoch [7/10], Validation Batch [200/250], Val Loss: 0.6050
# Validation, Train Loss: 0.7855, Val Loss: 0.7903
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [8/10]:
# 	 Batch [0/25000], Train Loss: 0.8501
# 	 Batch [200/25000], Train Loss: 0.9683
# 	 Batch [400/25000], Train Loss: 0.8447
# 	 Batch [600/25000], Train Loss: 0.8428
# 	 Batch [800/25000], Train Loss: 0.8448
# 	 Batch [1000/25000], Train Loss: 0.7233
# 	 Batch [1200/25000], Train Loss: 0.7297
# 	 Batch [1400/25000], Train Loss: 0.7248
# 	 Batch [1600/25000], Train Loss: 0.8375
# 	 Batch [1800/25000], Train Loss: 0.9737
# 	 Batch [2000/25000], Train Loss: 0.7070
# 	 Batch [2200/25000], Train Loss: 0.7207
# 	 Batch [2400/25000], Train Loss: 0.7374
# 	 Batch [2600/25000], Train Loss: 0.4823
# 	 Batch [2800/25000], Train Loss: 0.7101
# 	 Batch [3000/25000], Train Loss: 0.8609
# 	 Batch [3200/25000], Train Loss: 0.8526
# 	 Batch [3400/25000], Train Loss: 0.7263
# 	 Batch [3600/25000], Train Loss: 0.8482
# 	 Batch [3800/25000], Train Loss: 0.7239
# 	 Batch [4000/25000], Train Loss: 0.8509
# 	 Batch [4200/25000], Train Loss: 0.8568
# 	 Batch [4400/25000], Train Loss: 0.8460
# 	 Batch [4600/25000], Train Loss: 0.8499
# 	 Batch [4800/25000], Train Loss: 0.5899
# 	 Batch [5000/25000], Train Loss: 0.7224
# 	 Batch [5200/25000], Train Loss: 0.8429
# 	 Batch [5400/25000], Train Loss: 0.9611
# 	 Batch [5600/25000], Train Loss: 0.8484
# 	 Batch [5800/25000], Train Loss: 0.7082
# 	 Batch [6000/25000], Train Loss: 0.8572
# 	 Batch [6200/25000], Train Loss: 0.8351
# 	 Batch [6400/25000], Train Loss: 0.8405
# 	 Batch [6600/25000], Train Loss: 0.8500
# 	 Batch [6800/25000], Train Loss: 0.9646
# 	 Batch [7000/25000], Train Loss: 0.9762
# 	 Batch [7200/25000], Train Loss: 0.7360
# 	 Batch [7400/25000], Train Loss: 0.6003
# 	 Batch [7600/25000], Train Loss: 0.8559
# 	 Batch [7800/25000], Train Loss: 0.8457
# 	 Batch [8000/25000], Train Loss: 0.7409
# 	 Batch [8200/25000], Train Loss: 0.8523
# 	 Batch [8400/25000], Train Loss: 0.9797
# 	 Batch [8600/25000], Train Loss: 0.8488
# 	 Batch [8800/25000], Train Loss: 0.6003
# 	 Batch [9000/25000], Train Loss: 0.8665
# 	 Batch [9200/25000], Train Loss: 0.9800
# 	 Batch [9400/25000], Train Loss: 0.7289
# 	 Batch [9600/25000], Train Loss: 0.7342
# 	 Batch [9800/25000], Train Loss: 0.8507
# 	 Batch [10000/25000], Train Loss: 0.7295
# 	 Batch [10200/25000], Train Loss: 0.7227
# 	 Batch [10400/25000], Train Loss: 0.8420
# 	 Batch [10600/25000], Train Loss: 0.9828
# 	 Batch [10800/25000], Train Loss: 0.5996
# 	 Batch [11000/25000], Train Loss: 0.6003
# 	 Batch [11200/25000], Train Loss: 0.8433
# 	 Batch [11400/25000], Train Loss: 0.9632
# 	 Batch [11600/25000], Train Loss: 0.7217
# 	 Batch [11800/25000], Train Loss: 0.8467
# 	 Batch [12000/25000], Train Loss: 0.9791
# 	 Batch [12200/25000], Train Loss: 0.9729
# 	 Batch [12400/25000], Train Loss: 0.7196
# 	 Batch [12600/25000], Train Loss: 0.8520
# 	 Batch [12800/25000], Train Loss: 0.7224
# 	 Batch [13000/25000], Train Loss: 0.9828
# 	 Batch [13200/25000], Train Loss: 0.7263
# 	 Batch [13400/25000], Train Loss: 0.7123
# 	 Batch [13600/25000], Train Loss: 0.8502
# 	 Batch [13800/25000], Train Loss: 0.8477
# 	 Batch [14000/25000], Train Loss: 0.8446
# 	 Batch [14200/25000], Train Loss: 0.8358
# 	 Batch [14400/25000], Train Loss: 0.9827
# 	 Batch [14600/25000], Train Loss: 0.9779
# 	 Batch [14800/25000], Train Loss: 0.8622
# 	 Batch [15000/25000], Train Loss: 0.8542
# 	 Batch [15200/25000], Train Loss: 0.7357
# 	 Batch [15400/25000], Train Loss: 0.7140
# 	 Batch [15600/25000], Train Loss: 0.6006
# 	 Batch [15800/25000], Train Loss: 0.7221
# 	 Batch [16000/25000], Train Loss: 0.7191
# 	 Batch [16200/25000], Train Loss: 0.8419
# 	 Batch [16400/25000], Train Loss: 0.7352
# 	 Batch [16600/25000], Train Loss: 0.7326
# 	 Batch [16800/25000], Train Loss: 0.8617
# 	 Batch [17000/25000], Train Loss: 0.9772
# 	 Batch [17200/25000], Train Loss: 0.7152
# 	 Batch [17400/25000], Train Loss: 0.8386
# 	 Batch [17600/25000], Train Loss: 0.8601
# 	 Batch [17800/25000], Train Loss: 0.7191
# 	 Batch [18000/25000], Train Loss: 0.7270
# 	 Batch [18200/25000], Train Loss: 0.8534
# 	 Batch [18400/25000], Train Loss: 0.7251
# 	 Batch [18600/25000], Train Loss: 0.8488
# 	 Batch [18800/25000], Train Loss: 0.8608
# 	 Batch [19000/25000], Train Loss: 0.8476
# 	 Batch [19200/25000], Train Loss: 0.8552
# 	 Batch [19400/25000], Train Loss: 0.8428
# 	 Batch [19600/25000], Train Loss: 0.7182
# 	 Batch [19800/25000], Train Loss: 0.8538
# 	 Batch [20000/25000], Train Loss: 0.8370
# 	 Batch [20200/25000], Train Loss: 0.9751
# 	 Batch [20400/25000], Train Loss: 0.9754
# 	 Batch [20600/25000], Train Loss: 0.6027
# 	 Batch [20800/25000], Train Loss: 0.8424
# 	 Batch [21000/25000], Train Loss: 0.8445
# 	 Batch [21200/25000], Train Loss: 0.8501
# 	 Batch [21400/25000], Train Loss: 0.8482
# 	 Batch [21600/25000], Train Loss: 0.7375
# 	 Batch [21800/25000], Train Loss: 0.7318
# 	 Batch [22000/25000], Train Loss: 0.7246
# 	 Batch [22200/25000], Train Loss: 0.6026
# 	 Batch [22400/25000], Train Loss: 0.8516
# 	 Batch [22600/25000], Train Loss: 0.9682
# 	 Batch [22800/25000], Train Loss: 0.5914
# 	 Batch [23000/25000], Train Loss: 0.7241
# 	 Batch [23200/25000], Train Loss: 0.8522
# 	 Batch [23400/25000], Train Loss: 0.7213
# 	 Batch [23600/25000], Train Loss: 0.7313
# 	 Batch [23800/25000], Train Loss: 0.7401
# 	 Batch [24000/25000], Train Loss: 0.7270
# 	 Batch [24200/25000], Train Loss: 0.4738
# 	 Batch [24400/25000], Train Loss: 0.9726
# 	 Batch [24600/25000], Train Loss: 0.8500
# 	 Batch [24800/25000], Train Loss: 0.8400
# Epoch [8/10], Validation Batch [0/250], Val Loss: 0.8448
# Epoch [8/10], Validation Batch [100/250], Val Loss: 0.8397
# Epoch [8/10], Validation Batch [200/250], Val Loss: 0.5991
# Validation, Train Loss: 0.7856, Val Loss: 0.7906
# ****************************************************************************************************
# ****************************************************************************************************
# Epoch [9/10]:
# 	 Batch [0/25000], Train Loss: 0.9847
# 	 Batch [200/25000], Train Loss: 0.7234
# 	 Batch [400/25000], Train Loss: 0.8393
# 	 Batch [600/25000], Train Loss: 0.8589
# 	 Batch [800/25000], Train Loss: 0.9725
# 	 Batch [1000/25000], Train Loss: 0.8570
# 	 Batch [1200/25000], Train Loss: 0.8464
# 	 Batch [1400/25000], Train Loss: 0.7330
# 	 Batch [1600/25000], Train Loss: 0.9672
# 	 Batch [1800/25000], Train Loss: 0.8544
# 	 Batch [2000/25000], Train Loss: 0.7205
# 	 Batch [2200/25000], Train Loss: 0.7158
# 	 Batch [2400/25000], Train Loss: 0.8456
# 	 Batch [2600/25000], Train Loss: 0.7255
# 	 Batch [2800/25000], Train Loss: 0.8567
# 	 Batch [3000/25000], Train Loss: 0.9737
# 	 Batch [3200/25000], Train Loss: 0.8573
# 	 Batch [3400/25000], Train Loss: 0.5921
# 	 Batch [3600/25000], Train Loss: 0.7264
# 	 Batch [3800/25000], Train Loss: 0.7261
# 	 Batch [4000/25000], Train Loss: 0.8530
# 	 Batch [4200/25000], Train Loss: 0.8494
# 	 Batch [4400/25000], Train Loss: 0.7324
# 	 Batch [4600/25000], Train Loss: 0.9777
# 	 Batch [4800/25000], Train Loss: 0.6002
# 	 Batch [5000/25000], Train Loss: 0.9750
# 	 Batch [5200/25000], Train Loss: 0.7286
# 	 Batch [5400/25000], Train Loss: 0.5990
# 	 Batch [5600/25000], Train Loss: 0.7266
# 	 Batch [5800/25000], Train Loss: 0.9727
# 	 Batch [6000/25000], Train Loss: 0.8443
# 	 Batch [6200/25000], Train Loss: 0.7226
# 	 Batch [6400/25000], Train Loss: 0.5924
# 	 Batch [6600/25000], Train Loss: 0.8370
# 	 Batch [6800/25000], Train Loss: 0.7279
# 	 Batch [7000/25000], Train Loss: 0.5892
# 	 Batch [7200/25000], Train Loss: 0.5973
# 	 Batch [7400/25000], Train Loss: 0.7378
# 	 Batch [7600/25000], Train Loss: 0.7358
# 	 Batch [7800/25000], Train Loss: 0.8494
# ...
# 	 Batch [11000/25000], Train Loss: 0.9710
# 	 Batch [11200/25000], Train Loss: 0.7416
# 	 Batch [11400/25000], Train Loss: 0.8454
# 	 Batch [11600/25000], Train Loss: 0.8394
# 	 Batch [11800/25000], Train Loss: 0.9733
# 	 Batch [12000/25000], Train Loss: 0.7302
# 	 Batch [12200/25000], Train Loss: 0.9742
# 	 Batch [12400/25000], Train Loss: 0.8430
# 	 Batch [12600/25000], Train Loss: 0.8463
# 	 Batch [12800/25000], Train Loss: 0.9698
# 	 Batch [13000/25000], Train Loss: 0.8576
# 	 Batch [13200/25000], Train Loss: 0.7331
# 	 Batch [13400/25000], Train Loss: 0.8498
# 	 Batch [13600/25000], Train Loss: 0.7249
# 	 Batch [13800/25000], Train Loss: 0.7200
# 	 Batch [14000/25000], Train Loss: 0.7236
# 	 Batch [14200/25000], Train Loss: 0.8579
# 	 Batch [14400/25000], Train Loss: 0.7244
# 	 Batch [14600/25000], Train Loss: 0.7188
# 	 Batch [14800/25000], Train Loss: 0.8399
# 	 Batch [15000/25000], Train Loss: 0.8599
# 	 Batch [15200/25000], Train Loss: 0.7238
# 	 Batch [15400/25000], Train Loss: 0.8550
# 	 Batch [15600/25000], Train Loss: 0.8472
# 	 Batch [15800/25000], Train Loss: 0.4808
# 	 Batch [16000/25000], Train Loss: 0.7220
# 	 Batch [16200/25000], Train Loss: 0.8431
# 	 Batch [16400/25000], Train Loss: 0.6035
# 	 Batch [16600/25000], Train Loss: 0.7175
# 	 Batch [16800/25000], Train Loss: 0.7023
# 	 Batch [17000/25000], Train Loss: 0.5973
# 	 Batch [17200/25000], Train Loss: 0.8403
# 	 Batch [17400/25000], Train Loss: 0.8499
# 	 Batch [17600/25000], Train Loss: 0.6094
# 	 Batch [17800/25000], Train Loss: 0.7129
# 	 Batch [18000/25000], Train Loss: 0.9901
# 	 Batch [18200/25000], Train Loss: 0.5961
# 	 Batch [18400/25000], Train Loss: 0.9831
# 	 Batch [18600/25000], Train Loss: 0.8580
# 	 Batch [18800/25000], Train Loss: 0.7292
# 	 Batch [19000/25000], Train Loss: 0.8635
# 	 Batch [19200/25000], Train Loss: 0.7177
# 	 Batch [19400/25000], Train Loss: 0.9781
# 	 Batch [19600/25000], Train Loss: 0.6051
# 	 Batch [19800/25000], Train Loss: 0.8554
# 	 Batch [20000/25000], Train Loss: 0.8459
# 	 Batch [20200/25000], Train Loss: 0.7258
# 	 Batch [20400/25000], Train Loss: 0.7314
# 	 Batch [20600/25000], Train Loss: 0.8555
# 	 Batch [20800/25000], Train Loss: 0.7185
# 	 Batch [21000/25000], Train Loss: 0.7128
# 	 Batch [21200/25000], Train Loss: 0.6030
# 	 Batch [21400/25000], Train Loss: 0.9697
# 	 Batch [21600/25000], Train Loss: 0.5888
# 	 Batch [21800/25000], Train Loss: 0.7343
# 	 Batch [22000/25000], Train Loss: 0.8482
# 	 Batch [22200/25000], Train Loss: 0.5946
# 	 Batch [22400/25000], Train Loss: 0.7279
# 	 Batch [22600/25000], Train Loss: 0.5890
# 	 Batch [22800/25000], Train Loss: 0.8419
# 	 Batch [23000/25000], Train Loss: 0.7137
# 	 Batch [23200/25000], Train Loss: 0.8536
# 	 Batch [23400/25000], Train Loss: 0.7119
# 	 Batch [23600/25000], Train Loss: 0.5944
# 	 Batch [23800/25000], Train Loss: 0.7260
# 	 Batch [24000/25000], Train Loss: 0.8389
# 	 Batch [24200/25000], Train Loss: 0.7288
# 	 Batch [24400/25000], Train Loss: 0.5972
# 	 Batch [24600/25000], Train Loss: 0.7342
# 	 Batch [24800/25000], Train Loss: 0.8505
# Epoch [10/10], Validation Batch [0/250], Val Loss: 0.8372
# Epoch [10/10], Validation Batch [100/250], Val Loss: 0.8399
# Epoch [10/10], Validation Batch [200/250], Val Loss: 0.5913
# Validation, Train Loss: 0.7855, Val Loss: 0.7902
# ****************************************************************************************************
# Training completed.
# (SeverityModel(
#    (bestsimese50simclr): SiameseNetwork101(
#      (cnn1): ResNet(
#        (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#        (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#        (relu): ReLU(inplace=True)
#        (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#        (layer1): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#              (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (layer2): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#              (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (3): Bottleneck(
#            (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (layer3): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#              (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (3): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (4): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (5): Bottleneck(
#            (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (layer4): Sequential(
#          (0): Bottleneck(
#            (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#            (downsample): Sequential(
#              (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#              (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            )
#          )
#          (1): Bottleneck(
#            (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#          (2): Bottleneck(
#            (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#            (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#            (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#            (relu): ReLU(inplace=True)
#          )
#        )
#        (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#        (fc): Sequential(
#          (0): Linear(in_features=2048, out_features=1000, bias=True)
#          (1): ReLU()
#          (2): Dropout(p=0.1, inplace=False)
#          (3): Linear(in_features=1000, out_features=256, bias=True)
#        )
#        (fc2): Sequential(
#          (0): Linear(in_features=256, out_features=256, bias=True)
#          (1): ReLU()
#          (2): Dropout(p=0.1, inplace=False)
#          (3): Linear(in_features=256, out_features=256, bias=True)
#        )
#      )
#    )
#  ),
#  [0.7856561399567127,
#   0.7856109252893925,
#   0.7856040928900242,
#   0.7855776206731796,
#   0.7855538174951077,
#   0.7856087449979782,
#   0.785512260632515,
#   0.7855749808728695,
#   0.7854993648898602,
#   0.7855209830605984],
#  [0.7905242100954056,
#   0.7904630749225616,
#   0.7903412817716599,
#   0.7902627019882202,
#   0.790295382142067,
#   0.790185168504715,
#   0.790295790553093,
#   0.7906236329078674,
#   0.7904572373628617,
#   0.7902123907804489])
